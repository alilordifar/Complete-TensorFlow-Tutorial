# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# * Mixed precision is the use of both 16-bit and 32-bit floating-point types in a model during training to make it run faster and use less memory.
# * Today, most moderls use the float32 dtype, which takes 32 bits of memory.

# %%
# create a tensor with default datatype (float32)
A = tf.constant([4.5, 3.2])
A.dtype
# Out:
# tf.float32

# %%
B = tf.constant([9, 4])
B.dtype
# Out:
# tf.int32

# %%
# Change from float32 to float16 (Reduce Precision)
C = tf.cast(A, dtype = tf.float16)
C
# Out:
# <tf.Tensor: shape=(2,), dtype=float16, numpy=array([4.5, 3.2], dtype=float16)>

# %%
# Change from int32 to float32

D = tf.cast(B, dtype = tf.float32)
D
# Out:
# <tf.Tensor: shape=(2,), dtype=float32, numpy=array([9., 4.], dtype=float32)>
